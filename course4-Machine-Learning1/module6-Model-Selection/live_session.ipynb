# %%
'''
Theoretical Session on Model Selection by IIIT-B Professional
Agenda:

The session is divided into the following parts:

 * Introduction and Agenda 
 * Introduction to Model Selection 
 * Model and Learning Algorithm 
 * Simplicity, Complexity, and Overfitting 
 * Bias, Variance, and Tradeoff 
 * Comprehension: Bias-Variance Tradeoff
 * Regularization and Hyperparameter Tuning 
 * Model Evaluation and Cross-Validation 
 * Summary and Closing Remarks

'''
# Ramesh kestur
# Out:
# '\nTheoretical Session on Model Selection by IIIT-B Professional\nAgenda:\n\nThe session is divided into the following parts:\n\n * Introduction and Agenda \n * Introduction to Model Selection \n * Model and Learning Algorithm \n * Simplicity, Complexity, and Overfitting \n * Bias, Variance, and Tradeoff \n * Comprehension: Bias-Variance Tradeoff\n * Regularization and Hyperparameter Tuning \n * Model Evaluation and Cross-Validation \n * Summary and Closing Remarks\n\n'

# %%
# English 
'''
earlier it was better, now noisy
has static 
muffled now
its still having lot of noice
now static stopped
in between voice breaking
yes , breaking/cutting voice
'''
