# %%
# Introduction
'''
After this module, you should be able to apply some fundamental principles to choose appropriate models and critically evaluate the pros and 
cons of each one. The topics and some important jargons included in this session include the following:

 * Occam’s Razor 
 * Overfitting
 * Regularization
 * Bias-variance tradeoff
 * Model complexity

'''
# URL: https://github.com/ContentUpgrad/Model-Selection/tree/main/Model%20Evaluation

# %%
# Introduction to Model Selection
'''
'''
# Out:
# '\n'

# %%
# Model and Learning Algorithm

# %%
# Simplicity, Complexity and Overfitting

# %%
# Bias-Variance Tradeoff

# %%
# Comprehension - Bias Variance Tradeoff

# %%
# Regularization

# %%
# Summary

# %%
# Learner Outcome Journey
