# %%
# INtroduction
'''
You will understand Naive Bayes classifier through an example of mushrooms where the aim is to classify a new mushroom into edible or 
poisonous class. You will also learn that this algorithm uses probability to do such classification. You will follow the steps given 
below through the course of this session:

Bayes Theorem 
Naïve Bayes on Categorical data
'''

# %%
# Naive Bayes - With One Feature
'''

'''
# Out:
# '\n\n'

# %%
# Comprehension

# %%
# Conditional Independence in Naive Bayes

# %%
# Deciphering Naive Bayes

# %%
# Summary
