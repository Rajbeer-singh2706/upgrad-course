# %%
# Introduction
'''
Welcome to the module on ‘Naive Bayes’.
In this module, you will learn about another type of supervised classification, i.e. Naive Bayes. Naive Bayes is a probabilistic classifier 
which returns the probability of a test point belonging to a class rather than the label of the test point.

'''
# URL : https://github.com/ContentUpgrad/Naive-Bayes
# Out:
# '\nWelcome to the module on ‘Naive Bayes’.\nIn this module, you will learn about another type of supervised classification, i.e. Naive Bayes. Naive Bayes is a probabilistic classifier \nwhich returns the probability of a test point belonging to a class rather than the label of the test point.\n\n'

# %%
# Conditional Probability and Its Intuition
'''
'''
# Can you write the mathematical expression for the probability of an event E occurring?
P(E) = Number of favourable outcomes / Total number of possible outcomes

Conditional Probability
Why do you think you need conditional probability?

Conditional Probability
Can you think of some examples depicting conditional probability, with respect to the two new terms you just came across, i.e. prior and posterior?
# Out:
#   Cell In[1], line 5
#     P(E) = Number of favourable outcomes / Total number of possible outcomes
#     ^
# SyntaxError: cannot assign to function call

# %%
# Bayes' Theorem
