# %%
## INtroduction 
'''
In this session, you will learn how to:

- Build a multivariate logistic regression model in Python
- Conduct feature selection for logistic regression using:
    * Automated methods: RFE -Recursive Feature Elimination
    * Manual methods: VIF and p-value check

We will use the Telecom Churn dataset in this session to build a model using multivariate logistic regression. This will involve all the 
familiar steps such as:
  * Data cleaning and preparation
  * Preprocessing steps
  * Test-train split
  * Feature scaling
  * Model Building using RFE, p-values and VIFs
'''
# Out:
# '\nIn this session, you will learn how to:\n\n- Build a multivariate logistic regression model in Python\n- Conduct feature selection for logistic regression using:\n    * Automated methods: RFE -Recursive Feature Elimination\n    * Manual methods: VIF and p-value check\n\nWe will use the Telecom Churn dataset in this session to build a model using multivariate logistic regression. This will involve all the \nfamiliar steps such as:\n  * Data cleaning and preparation\n  * Preprocessing steps\n  * Test-train split\n  * Feature scaling\n  * Model Building using RFE, p-values and VIFs\n'

# %%
# Multivariate Logistic Regression - Telecom Churn Example
'''
'''
# https://github.com/ContentUpgrad/Logistic-Regression/blob/main/Multivariate%20Logistic%20Regression%20-%20Model%20Building/Logistic%2BRegression%2B-%2BTelecom%2BChurn%2BCase%2BStudy%20(1)%20(1).ipynb
# Out:
# '\n'

# %%
# Data Cleaning and Preparation - I
'''
'''
# Out:
# '\n'

# %%
# Data Cleaning and Preparation - II
# Out:
# '\n'

# %%
# Building your First Model

# %%
# Feature Elimination using RFE

# %%
# Confusion Matrix and Accuracy

# %%
# Manual Feature Elimination

# %%
# Summary
