# %%
# Introduction

# %%
# Reading and Understanding the Data
# URL : 
https://github.com/ContentUpgrad/Linear-Regression/tree/main
# Out:
#   Cell In[1], line 3
#     https://github.com/ContentUpgrad/Linear-Regression/tree/main
#           ^
# SyntaxError: invalid syntax

# %%
# Data Preparation
'''
Encoding Variables
Suppose you performed encoding with the variable ‘BloodGroup’ having four levels, ‘A’, ‘B’, ‘AB’, and ‘O’. To perform the encoding, you wish to drop two of the levels, ‘AB’ and ‘O’. Suggest a suitable encoding process that will now represent the four levels.
'''

### 
'''
For encoding the `BloodGroup` variable with four levels (‘A’, ‘B’, ‘AB’, and ‘O’) and dropping two levels (‘AB’ and ‘O’), you can use **binary encoding** like **one-hot encoding**, where you generate binary variables for the remaining levels ('A' and 'B'). Since you want to drop two levels, a simple way would be using **dummy variable encoding** with the two remaining categories.

Here’s how the encoding would look:

1. **Create two new binary columns**: `BloodGroup_A` and `BloodGroup_B`.
2. **Assign binary values** to these columns as follows:
   - BloodGroup ‘A’ → `BloodGroup_A = 1`, `BloodGroup_B = 0`
   - BloodGroup ‘B’ → `BloodGroup_A = 0`, `BloodGroup_B = 1`
   - BloodGroup ‘AB’ (dropped level) → `BloodGroup_A = 0`, `BloodGroup_B = 0`
   - BloodGroup ‘O’ (dropped level) → `BloodGroup_A = 0`, `BloodGroup_B = 0`

In this approach, any row where the original variable was 'AB' or 'O' will be represented as all zeros in the new binary columns. This process ensures you can still use the other levels without over-representing the dropped categories.

'''

###
'''

A - 10
B - 01
AB - 11
O - 00
Note that this encoding is not exactly dummy encoding; it’s just manual encoding that you performed.


'''
# Out:
# "\nFor encoding the `BloodGroup` variable with four levels (‘A’, ‘B’, ‘AB’, and ‘O’) and dropping two levels (‘AB’ and ‘O’), you can use **binary encoding** like **one-hot encoding**, where you generate binary variables for the remaining levels ('A' and 'B'). Since you want to drop two levels, a simple way would be using **dummy variable encoding** with the two remaining categories.\n\nHere’s how the encoding would look:\n\n1. **Create two new binary columns**: `BloodGroup_A` and `BloodGroup_B`.\n2. **Assign binary values** to these columns as follows:\n   - BloodGroup ‘A’ → `BloodGroup_A = 1`, `BloodGroup_B = 0`\n   - BloodGroup ‘B’ → `BloodGroup_A = 0`, `BloodGroup_B = 1`\n   - BloodGroup ‘AB’ (dropped level) → `BloodGroup_A = 0`, `BloodGroup_B = 0`\n   - BloodGroup ‘O’ (dropped level) → `BloodGroup_A = 0`, `BloodGroup_B = 0`\n\nIn this approach, any row where the original variable was 'AB' or 'O' will be represented as all zeros in the new binary columns. This process ensures you 
# ...

# %%
# Initial Steps

# %%
# Building the Model - I

# %%
# Building the Model - II

# %%
# Residual Analysis and Predictions

# %%
#Variable Selection using RFE
